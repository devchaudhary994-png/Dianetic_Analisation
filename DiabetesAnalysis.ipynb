# %%
import pandas as pd

# %%
df=pd.read_csv("/content/diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.shape
# Out:
# (768, 9)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
# to know about the datset fully
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# to find the missisng value
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# to find the duplicate values in the dataset
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# to finmd the unique values
df.nunique()
# Out:
# Pregnancies                  17
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %%
# to check the invalis zero values
(df[['Glucose','BloodPressure','SkinThickness','Insulin','BMI']]==0).sum()
# Out:
# Glucose            5
# BloodPressure     35
# SkinThickness    227
# Insulin          374
# BMI               11
# dtype: int64

# %%
# for selecting and filterimg
# select only thge single column
df['Glucose']
# Out:
# 0      148
# 1       85
# 2      183
# 3       89
# 4      137
#       ...
# 763    101
# 764    122
# 765    121
# 766    126
# 767     93
# Name: Glucose, Length: 768, dtype: int64

# %%
# to select the multiple columns
df[['Glucose','BMI','Age']]
# Out:
#      Glucose   BMI  Age
# 0        148  33.6   50
# 1         85  26.6   31
# 2        183  23.3   32
# 3         89  28.1   21
# 4        137  43.1   33
# ..       ...   ...  ...
# 763      101  32.9   63
# 764      122  36.8   27
# 765      121  26.2   30
# 766      126  30.1   47
# 767       93  30.4   23
#
# [768 rows x 3 columns]

# %%
# to filter the rows with the help of columns
df[df['Age']>50]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 12            10      139             80              0        0  27.1
# 13             1      189             60             23      846  30.1
# 14             5      166             72             19      175  25.8
# ..           ...      ...            ...            ...      ...   ...
# 719            5       97             76             27        0  35.6
# 734            2      105             75              0        0  23.3
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 763           10      101             76             48      180  32.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 8                       0.158   53        1
# ...

# %%
# to filter with multiple condition
df[(df['Age']>50) & (df['Outcome']==1)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 8              2      197             70             45      543  30.5
# 9              8      125             96              0        0   0.0
# 13             1      189             60             23      846  30.1
# 14             5      166             72             19      175  25.8
# 24            11      143             94             33      146  36.6
# 39             4      111             72             47      207  37.1
# 43             9      171            110             24      240  45.4
# 53             8      176             90             34      300  33.7
# 93             4      134             72              0        0  23.8
# 115            4      146             92              0        0  31.2
# 129            0      105             84              0        0  27.9
# 186            8      181             68             36      495  30.1
# ...

# %%
# to access rows by index
df.iloc[100:105]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 100            1      163             72              0        0  39.0
# 101            1      151             60              0        0  26.1
# 102            0      125             96              0        0  22.5
# 103            1       81             72             18       40  26.6
# 104            2       85             65              0        0  39.6
#
#      DiabetesPedigreeFunction  Age  Outcome
# 100                     1.222   33        1
# 101                     0.179   22        0
# 102                     0.262   21        0
# 103                     0.283   24        0
# 104                     0.930   27        0

# %%
 # sorting and grouping
 df.sort_values(by='Age',ascending=False).head()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 459            9      134             74             33       60  25.9
# 453            2      119              0              0        0  19.6
# 666            4      145             82             18        0  32.5
# 684            5      136             82              0        0   0.0
# 123            5      132             80              0        0  26.8
#
#      DiabetesPedigreeFunction  Age  Outcome
# 459                     0.460   81        0
# 453                     0.832   72        0
# 666                     0.235   70        1
# 684                     0.640   69        0
# 123                     0.186   69        0

# %%
# with value count
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64
